# %%
import numpy as np

from scipy.spatial import Delaunay

points = np.random.uniform(0, 100, (10, 2))

points
# Out:
# array([[ 4.62702287, 50.57070014],
#        [ 5.13722428, 79.13994288],
#        [99.5689893 , 75.37791762],
#        [65.96099325, 71.92424071],
#        [44.14237967, 15.5340301 ],
#        [30.63745822, 99.6294729 ],
#        [16.8750898 , 84.07767461],
#        [25.73342725, 31.89946224],
#        [42.6894641 , 65.35467103],
#        [82.18796963, 71.40559362]])

# %%
tri = Delaunay(points)

def baricenter(points, tri):
    return np.array([(points[a, :] + points[b, :] + points[c, :])/3 for a, b, c in tri.simplices])

baricenters = baricenter(points, tri)

# %%
import matplotlib.pyplot as plt
plt.triplot(points[:,0], points[:,1], tri.simplices)
plt.plot(points[:,0], points[:,1], 'o')
plt.plot(points[:,0], points[:,1], 'o')
plt.plot(baricenters[:,0], baricenters[:,1], 'o')
plt.show()

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('http://elib.zib.de/pub/mp-testdata/tsp/tsplib/tsp/a280.tsp')[5:-1].set_axis(['coor'], axis = 1)
dataframe[['First', 'x', 'y']] = dataframe.coor.str.split(expand=True,)
dataframe[['x', 'y']].to_csv('instancias_tsplib/a280.csv', index = False)

# %%
pd.read_html('http://elib.zib.de/pub/mp-testdata/tsp/tsplib/tsp/index.html')
# Out:
# [                           0                   1             2
#  0  Last update: June 1, 1995  Georg Skorobohatyj  ZIB Homepage]

# %%
names = pd.read_table('./instancias_tsplib/instances.txt').set_axis(['Names'], axis = 1)
names['Names'] = names.Names.str.split(expand=True,).iloc[:, 0]

# %%
# for nombre in list(names['Names']):
#     print(nombre)
#     a, b = nombre.split(".")
#     print(a)
#     print(b)
#     try:
#         dataframe = pd.read_csv('http://elib.zib.de/pub/mp-testdata/tsp/tsplib/tsp/' + str(nombre))[5:-1].set_axis(['coor'], axis = 1)
#         dataframe[['First', 'x', 'y']] = dataframe.coor.str.split(expand=True,)
#         dataframe[['x', 'y']].to_csv('instancias_tsplib/' + str(a) + '.csv', index = False)
#     except:
#         print("No se puede")
# Out:
# a280.tsp
# a280
# tsp
# ali535.tsp
# ali535
# tsp
# att48.tsp
# att48
# tsp
# att532.tsp
# att532
# tsp
# bayg29.tsp
# bayg29
# tsp
# No se puede
# bays29.tsp
# bays29
# tsp
# No se puede
# berlin52.tsp
# berlin52
# tsp
# bier127.tsp
# bier127
# tsp
# brazil58.tsp
# brazil58
# tsp
# No se puede
# brd14051.tsp
# brd14051
# tsp
# brg180.tsp
# brg180
# tsp
# No se puede
# burma14.tsp
# burma14
# tsp
# ch130.tsp
# ch130
# tsp
# ch150.tsp
# ch150
# tsp
# d1291.tsp
# d1291
# tsp
# d1655.tsp
# d1655
# tsp
# d18512.tsp
# d18512
# tsp
# d198.tsp
# d198
# tsp
# d2103.tsp
# d2103
# tsp
# d493.tsp
# d493
# tsp
# d657.tsp
# d657
# tsp
# dantzig42.tsp
# dantzig42
# tsp
# No se puede
# dsj1000.tsp
# dsj1000
# tsp
# eil101.tsp
# eil101
# tsp
# eil51.tsp
# eil51
# tsp
# eil76.tsp
# eil76
# tsp
# fl1400.tsp
# fl1400
# tsp
# fl1577.tsp
# fl1577
# tsp
# fl3795.tsp
# fl3795
# tsp
# fl417.tsp
# fl417
# tsp
# fnl4461.tsp
# fnl4461
# tsp
# fri26.tsp
# fri26
# tsp
# No se puede
# gil262.tsp
# gil262
# tsp
# gr120.tsp
# gr120
# tsp
# No se puede
# gr137.tsp
# gr137
# tsp
# gr17.tsp
# gr17
# tsp
# No se puede
# gr202.tsp
# gr202
# tsp
# gr21.tsp
# gr21
# tsp
# No se puede
# gr229.tsp
# gr229
# tsp
# gr24.tsp
# gr24
# tsp
# No se puede
# gr431.tsp
# gr431
# tsp
# gr48.tsp
# gr48
# tsp
# No se puede
# gr666.tsp
# gr666
# tsp
# gr96.tsp
# gr96
# tsp
# hk48.tsp
# hk48
# tsp
# No se puede
# kroa100.tsp
# kroa100
# tsp
# No se puede
# kroa150.tsp
# kroa150
# tsp
# No se puede
# kroa200.tsp
# kroa200
# tsp
# No se puede
# krob100.tsp
# krob100
# tsp
# No se puede
# krob150.tsp
# krob150
# tsp
# No se puede
# krob200.tsp
# krob200
# tsp
# No se puede
# kroc100.tsp
# kroc100
# tsp
# No se puede
# krod100.tsp
# krod100
# tsp
# No se puede
# kroe100.tsp
# kroe100
# tsp
# No se puede
# lin105.tsp
# lin105
# tsp
# lin318.tsp
# lin318
# tsp
# linhp318.tsp
# linhp318
# tsp
# nrw1379.tsp
# nrw1379
# tsp
# p654.tsp
# p654
# tsp
# pa561.tsp
# pa561
# tsp
# No se puede
# pcb1173.tsp
# pcb1173
# tsp
# pcb3038.tsp
# pcb3038
# tsp
# pcb442.tsp
# pcb442
# tsp
# pla33810.tsp
# pla33810
# tsp
# pla7397.tsp
# pla7397
# tsp
# pla85900.tsp
# pla85900
# tsp
# pr1002.tsp
# pr1002
# tsp
# pr107.tsp
# pr107
# tsp
# pr124.tsp
# pr124
# tsp
# pr136.tsp
# pr136
# tsp
# pr144.tsp
# pr144
# tsp
# pr152.tsp
# pr152
# tsp
# pr226.tsp
# pr226
# tsp
# pr2392.tsp
# pr2392
# tsp
# pr264.tsp
# pr264
# tsp
# pr299.tsp
# pr299
# tsp
# pr439.tsp
# pr439
# tsp
# pr76.tsp
# pr76
# tsp
# rat195.tsp
# rat195
# tsp
# rat575.tsp
# rat575
# tsp
# rat783.tsp
# rat783
# tsp
# rat99.tsp
# rat99
# tsp
# rd100.tsp
# rd100
# tsp
# rd400.tsp
# rd400
# tsp
# rl11849.tsp
# rl11849
# tsp
# rl1304.tsp
# rl1304
# tsp
# rl1323.tsp
# rl1323
# tsp
# rl1889.tsp
# rl1889
# tsp
# rl5915.tsp
# rl5915
# tsp
# rl5934.tsp
# rl5934
# tsp
# si1032.tsp
# si1032
# tsp
# No se puede
# si175.tsp
# si175
# tsp
# No se puede
# si535.tsp
# si535
# tsp
# No se puede
# st70.tsp
# st70
# tsp
# swiss42.tsp
# swiss42
# tsp
# No se puede
# ts225.tsp
# ts225
# tsp
# No se puede
# tsp225.tsp
# tsp225
# tsp
# u1060.tsp
# u1060
# tsp
# u1432.tsp
# u1432
# tsp
# u159.tsp
# u159
# tsp
# u1817.tsp
# u1817
# tsp
# u2152.tsp
# u2152
# tsp
# u2319.tsp
# u2319
# tsp
# u574.tsp
# u574
# tsp
# u724.tsp
# u724
# tsp
# ulysses16.tsp
# ulysses16
# tsp
# ulysses22.tsp
# ulysses22
# tsp
# usa13509.tsp
# usa13509
# tsp
# No se puede
# vm1084.tsp
# vm1084
# tsp
# vm1748.tsp
# vm1748
# tsp

# %%
pd.read_csv('instancias_tsplib/ulysses22.csv').plot.scatter(x = 'x', y = 'y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
pd.read_csv('instancias_tsplib/ulysses16.csv').plot.scatter(x = 'x', y = 'y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
from generador import interseccion_long, d_PB, genera_separacion, no_cortan, cortan
import numpy as np
import pandas as pd
from neighborhood import Circle
import matplotlib.pyplot as plt

# %%
V = np.array(pd.read_csv('instancias_tsplib/ulysses16.csv'))
V

x_min, y_min = np.min(V, axis = 0)

if x_min < 0:
    V[:, 0] = V[:, 0] + abs(x_min)+0.5
if y_min < 0:
    V[:, 1] = V[:, 1] + abs(y_min)+0.5

# %%
r_init = 1

barreras = []
for i in range(10):
    # print(i)
    for punto1 in V:
        for punto2 in V:
            if any(punto1 != punto2):
                if all([no_cortan([punto1, punto2], barrera) for barrera in barreras]):
                    r = r_init
                    P1, P2 = genera_separacion(punto1, punto2, r)
                    while any([not(no_cortan([P1, P2], barrera)) for barrera in barreras]):
                        r = r / 2
                        # print(r)
                        P1, P2 = genera_separacion(punto1, punto2, r)
                    barreras.append([P1, P2])

# %%
barreras
# Out:
# [[array([37.93089611, 29.2211009 ]), array([39.87910389, 28.7688991 ])],
#  [array([36.443595  , 26.88863634]), array([38.056405  , 28.07136366])],
#  [array([36.76089604, 20.75596507]), array([34.95910396, 21.62403493])],
#  [array([38.89660397, 21.93265605]), array([36.90339603, 22.09734395])],
#  [array([37.85223293, 25.14038558]), array([37.90776707, 27.13961442])],
#  [array([40.7018418 , 20.72537606]), array([38.7681582 , 20.21462394])],
#  [array([39.40902606, 26.49315021]), array([38.19097394, 24.90684979])],
#  [array([40.70746567, 32.21131447]), array([39.42253433, 30.67868553])],
#  [array([38.59021992, 29.60738352]), array([37.23978008, 31.08261648])],
#  [array([40.47498592, 24.75236529]), array([38.50501408, 25.09763471])],
#  [array([41.89414795, 22.96127183]), array([39.89585205, 22.87872817])],
#  [array([40.93898042, 27.94604575]), array([38.98101958, 28.35395425])],
#  [array([35.84644207, 22.32422027]), array([33.89355793, 22.75577973])],
#  [array([35.14508617, 18.00205966]), array([35.89491383, 16.14794034])],
#  [array([37.53767979, 16.51317246]), array([37.17232021, 14.54682754])],
#  [array([35.76664671,  8.53787501]), array([33.79335329,  8.21212499])],
#  [array([34.74071022, 19.22154164]), array([36.24928978, 17.90845836])],
#  [array([37.25947306, 19.04288388]), array([38.72052694, 17.67711612])],
#  [array([40.03907156, 17.11996525]), array([38.75092844, 15.59003475])],
#  [array([36.16643243, 18.61653293]), array([36.88356757, 19.31346707])],
#  [array([39.81681299, 19.78976207]), array([39.77318701, 17.79023793])],
#  [array([37.4453062, 19.8547449]), array([39.4446938, 19.8052551])],
#  [array([36.57329843, 18.50071438]), array([37.33670157, 20.34928562])],
#  [array([40.20011535, 16.76981188]), array([42.19988465, 16.80018812])],
#  [array([39.59592094,  7.31637367]), array([37.71407906,  7.99362633])],
#  [array([37.74347118, 20.12595808]), array([38.87652882, 21.77404192])],
#  [array([37.96537279, 20.48867453]), array([37.69462721, 21.45132547])],
#  [array([36.6939265 , 19.99413938]), array([36.3060735 , 20.91586062])]]

# %%
Circles = []
bolas = []

def ve(punto, segmento):
    barrera1 = [punto, segmento[0]]
    flag1 = all([no_cortan(barrera1, barrera) for barrera in barreras])
    barrera2 = [punto, segmento[1]]
    flag2 = all([no_cortan(barrera2, barrera) for barrera in barreras])

    return flag1 | flag2

for v in V:

    r_min = min([interseccion_long(v, barrera) for barrera in barreras if ve(v, barrera)])
    upper_bound = min(r_min, min([d_PB(v, barrera) for barrera in barreras]))
    radii = np.random.uniform(upper_bound, upper_bound)
    Circles.append(Circle(center = v, radii = radii))
    bolas.append([v[0], v[1], radii])
    
print(bolas)
# Out:
# [[38.24, 26.130000000000003, 0.27185872864243604], [39.57, 31.86, 0.5100422523211281], [40.56, 31.03, 0.15202659659528972], [36.26, 28.830000000000002, 0.0889240547928411], [33.48, 16.25, 0.17514258044520803], [37.56, 17.9, 0.013939893069625944], [38.42, 18.82, 0.014138935683519071], [37.52, 26.150000000000002, 0.2807982622416276], [41.23, 14.809999999999999, 0.38082686967417423], [41.17, 18.76, 0.049275075800192435], [36.08, 0.5, 0.8859569931234808], [38.47, 20.84, 0.010908534422183563], [38.15, 21.06, 0.19416487838947868], [37.51, 20.88, 0.0393041579061393], [35.49, 20.03, 0.03439504355447305], [39.36, 25.27, 0.008138760766161818]]

# %%
fig, ax = plt.subplots()

for x, y, r in bolas:
    ax.scatter(x, y, s = 100*r)

for b in barreras:
    ax.plot([b[0][0], b[1][0]], [b[0][1], b[1][1]], c = 'red')
    
ax.set_aspect('equal')

# %%
# # De forma aleatoria
r_init = 1

np.random.seed(5)
def genera_separacion_aleatoria(punto1, punto2, r):
    param = np.random.uniform(0, 1)
    p_int = param*np.array(punto1) + (1-param)*np.array(punto2)
    theta1 = np.random.uniform(0, 2*np.pi)
    theta2 = np.random.uniform(0, 2*np.pi)
    P1 = p_int + np.array([r*np.cos(theta1), r*np.sin(theta1)])
    P2 = p_int + np.array([r*np.cos(theta2), r*np.sin(theta2)])
    
    return P1, P2
    
barreras = []
for i in range(10):
    # print(i)
    for punto1 in V:
        for punto2 in V:
            if any(punto1 != punto2):
                if all([no_cortan([punto1, punto2], barrera) for barrera in barreras]):
                    r = r_init
                    P1, P2 = genera_separacion_aleatoria(punto1, punto2, r)
                    while any([not(no_cortan([P1, P2], barrera)) for barrera in barreras]):
                        r = r / 2
                        # print(r)
                        P1, P2 = genera_separacion_aleatoria(punto1, punto2, r)
                    barreras.append([P1, P2])

                    Circles = []
bolas = []

def ve(punto, segmento):
    barrera1 = [punto, segmento[0]]
    flag1 = all([no_cortan(barrera1, barrera) for barrera in barreras])
    barrera2 = [punto, segmento[1]]
    flag2 = all([no_cortan(barrera2, barrera) for barrera in barreras])

    return flag1 | flag2

for v in V:

    r_min = min([interseccion_long(v, barrera) for barrera in barreras if ve(v, barrera)])
    upper_bound = min([d_PB(v, barrera) for barrera in barreras if ve(v, barrera)])
    radii = np.random.uniform(upper_bound, upper_bound)
    Circles.append(Circle(center = v, radii = radii))
    bolas.append([v[0], v[1], radii])

# %%
# fig, ax = plt.subplots()

# for x, y, r in bolas:
#     ax.scatter(x, y, s = 100*r)

# for b in barreras:
#     ax.plot([b[0][0], b[1][0]], [b[0][1], b[1][1]], c = 'red')
    
# # ax.set_aspect('equal')

# %%
from tspn_b import tspn_b

# %%
resultados = tspn_b(barreras, Circles, A4 = True, dominant=False, prepro=True, log=False, picture=True, time_limit=3600, init = False)
# Out:
# Set parameter Threads to value 6
# Set parameter TimeLimit to value 3600
# Set parameter NumericFocus to value 1
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 8 physical cores, 16 logical processors, using up to 6 threads
# Optimize a model with 5258403 rows, 4167446 columns and 9673324 nonzeros
# Model fingerprint: 0x8d4c41e7
# Model has 4494 quadratic constraints
# Variable types: 37276 continuous, 4130170 integer (4130170 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 2e+03]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e-02, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-02, 2e+03]
#   QRHS range       [4e-02, 1e+02]
# Presolve removed 5155036 rows and 4104705 columns (presolve time = 5s) ...
# Presolve removed 5158928 rows and 4104799 columns (presolve time = 10s) ...
# Presolve removed 5158930 rows and 4104799 columns (presolve time = 28s) ...
# Presolve removed 5158930 rows and 4108441 columns (presolve time = 32s) ...
# Presolve removed 5158930 rows and 4108441 columns (presolve time = 50s) ...
# Presolve removed 5168779 rows and 4111503 columns (presolve time = 58s) ...
# Presolve removed 5168799 rows and 4111522 columns (presolve time = 64s) ...
# Presolve removed 5168815 rows and 4111528 columns (presolve time = 66s) ...
# Presolve removed 5168767 rows and 4111526 columns
# Presolve time: 65.62s
# Presolved: 89636 rows, 55920 columns, 312819 nonzeros
# Presolved model has 4432 quadratic constraint(s)
# Variable types: 19256 continuous, 36664 integer (36662 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing first log only...
#
# Root relaxation presolve removed 13410 rows and 17349 columns
# Root relaxation presolved: 76226 rows, 38571 columns, 283949 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.719217e+02   4.899688e+09     67s
#    14431    1.2211536e+00   0.000000e+00   0.000000e+00     68s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                68s
#
#     3551 PPushes remaining with PInf 0.0000000e+00                68s
#        0 PPushes remaining with PInf 0.0000000e+00                68s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.3666471e-03     68s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    18423    1.2211536e+00   0.000000e+00   2.366647e-03     68s
#    18426    1.2211536e+00   0.000000e+00   0.000000e+00     68s
#    18426    1.2211536e+00   0.000000e+00   0.000000e+00     68s
# Concurrent spin time: 0.15s
#
# Solved with primal simplex (dual model)
#
# Root relaxation: objective 1.221154e+00, 16055 iterations, 1.85 seconds (1.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1